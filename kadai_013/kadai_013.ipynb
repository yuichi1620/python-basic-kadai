# %%
def calc_tax(price:int, tax_rate:int) -> int:
    # 消費税を加えた計算して返す
    tax = price * tax_rate / 100
    return price + tax

# 第一引数: 価格 110
# 第二引数: 消費税　10%
result = calc_tax(110, 10)
result
# Out:
# 121.0
