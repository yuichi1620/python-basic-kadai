# %%
class Human:
    def __init__(self, name: str, age: int):
        # 属性を定義
        self.name = name
        self.age = age

    def check_adult(self):
        # 成人かどうかを判定するメソッド
        if self.age >= 20:
            print(f"{self.name}さんは大人です。")
        else:
            print(f"{self.name}さんは大人ではありません。")

#  Humanクラスのインスタンスを作成
persons = [
    Human("雄一", 25),
    Human("花子", 18),
    Human("太郎", 30)
]

# 各インスタンスの成人判定メソッドを呼び出す
for person in persons:
    person.check_adult()
# Out:
# 雄一さんは大人です。
# 花子さんは大人ではありません。
# 太郎さんは大人です。
