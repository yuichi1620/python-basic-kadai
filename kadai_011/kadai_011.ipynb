# %%
arrays = ["水","金","地","火","木","土","天","海","冥"]

# for文
for array in arrays:
    print(array)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
arrays = ["水","金","地","火","木","土","天","海","冥"]

# while文
i = 0
while i < len(arrays):
    print(arrays[i])
    i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
